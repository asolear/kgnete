# %%
if 1:
    if 1:
        exec(open("aa.py").read())
        archivos.cname()
        archivos.authors()


        o = SimpleNamespace()
        carpeta_destino="/home/pk/Desktop/mkdocs/docs/blog/posts"
        
        directorios= ["/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica"]

        for directorio in directorios:
            print(directorio)
            o.files, o.nombres, o.listaCategorias, o.fechas = obtener_archivos_con_rutas(directorio)
            print(o.files, o.nombres, o.listaCategorias, o.fechas)
            for ii, file in enumerate(o.files):
                
                imagenes(o.files[ii],o.nombres[ii], f"{carpeta_destino}/{o.nombres[ii]}", resolucion_dpi=100)
                md(o.nombres[ii],o.fechas[ii],o.listaCategorias[ii])
# Out:
# /home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica
# ['/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/07_PRESUPUESTO/zRES.pdf', '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/02_MEMORIA/zRES.pdf', '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/01_INDICE/zRES.pdf', '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/06_MEDICIONES/zRES.pdf', '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/05_PLIEGO DE CONDICIONES/zRES.pdf'] ['PRESUPUESTO', 'MEMORIA', 'INDICE', 'MEDICIONES', 'PLIEGO DE CONDICIONES'] [['Fotovoltaica'], ['Fotovoltaica'], ['Fotovoltaica'], ['Fotovoltaica'], ['Fotovoltaica']] ['2024-02-22', '2024-02-22', '2024-02-22', '2024-02-22', '2024-02-22']

# %%
o.archivos
# Out:
# ['/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/07_PRESUPUESTO',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/02_MEMORIA',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/01_INDICE',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/06_MEDICIONES',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/08_ANEJOS',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/03_ANEXOS',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/05_PLIEGO DE CONDICIONES',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/04_PLANOS',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/07_PRESUPUESTO/zRES.pdf',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/07_PRESUPUESTO/XXXX.py',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/07_PRESUPUESTO/aDOC.md',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/02_MEMORIA/zRES.pdf',
#  '/home/pk/Desktop/pdfs/docs/Proyectos/Fotovoltaica/02_MEMORIA/XXXX.py',
# ...

# %%
exec(open("aa.py").read())
if 1:
    if 1:
        o = SimpleNamespace()
        carpeta_destino="/home/pk/Desktop/mkdocs/docs/blog/posts"
        directorio_origen = "/home/pk/Desktop/pdfs/docs/aa"
        o.files, o.nombres, o.listaCategorias, o.fechas = obtener_archivos_con_rutas(directorio_origen)
        print(o.files, o.nombres, o.listaCategorias, o.fechas)
    if 1:
        for ii, file in enumerate(o.files):

            imagenes(o.files[ii],o.nombres[ii], f"{carpeta_destino}/{o.nombres[ii]}", resolucion_dpi=100)
            md(o.nombres[ii],o.fechas[ii],o.listaCategorias[ii])
# Out:
# ['/home/pk/Desktop/pdfs/docs/aa/0200_AA Muestra de docuemnto/zz.pdf', '/home/pk/Desktop/pdfs/docs/aa/0200_AA Muestra de docuemnto copy/zz.pdf'] ['AA Muestra de docuemnto', 'AA Muestra de docuemnto copy'] [['aa'], ['aa']] ['2024-02-21', '2024-02-21']

# %%
o.files
# Out:
# ['/home/pk/Desktop/pdfs/docs/aa/0200_AA Muestra de docuemnto/zz.pdf',
#  '/home/pk/Desktop/pdfs/docs/aa/0200_AA Muestra de docuemnto copy/zz.pdf']

# %%
# Cambiamos al directorio que contiene el script
os.path.basename(os.path.dirname('/home/pk/Desktop/pdfs/docs/aa/0200_AA Muestra de docuemnto/zz.pdf'))
# Out:
# '0200_AA Muestra de docuemnto'

# %%
file = '/home/pk/Desktop/web_pdfs_qroman17/docs/Tramites y Permisos/Tramitacion FV/Permisos/Licencia_Obras/Declaración Responsable de Obras.pdf'
pdf_path, archivo = os.path.split(file)
pdf_path
# Out:
# '/home/pk/Desktop/web_pdfs_qroman17/docs/Tramites y Permisos/Tramitacion FV/Permisos/Licencia_Obras'

# %%
    pdf_path, archivo = os.path.split(file)
    # Convierte el PDF a una lista de imágenes
    ruta_carpeta = f"{carpeta_destino}/{archivo[:-4]}"
    if os.path.exists(ruta_carpeta):
        # Si existe, la borra con todo su contenido
        shutil.rmtree(ruta_carpeta)
    os.mkdir(ruta_carpeta)

# %%
imagenes = convert_from_path(file, dpi=300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pdf2image/pdf2image.py:589, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     588 if "Pages" not in d:
# --> 589     raise ValueError
#     591 return d
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 imagenes = convert_from_path(file, dpi=300)
#
# File ~/.local/lib/python3.10/site-packages/pdf2image/pdf2image.py:127, in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, ownerpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo, timeout, hide_annotations)
# ...

# %%
exec(open("pp.py").read())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pdf2image/pdf2image.py:589, in pdfinfo_from_path(pdf_path, userpw, ownerpw, poppler_path, rawdates, timeout)
#     588 if "Pages" not in d:
# --> 589     raise ValueError
#     591 return d
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 exec(open("pp.py").read())
#
# File <string>:96
#
# File <string>:13, in imagenes(file, carpeta_destino, resolucion_dpi)
#
# ...

# %%
dates = [tupla[1] for tupla in tuplas]
fechas=[datetime.datetime.fromtimestamp(date).strftime('%Y-%m-%d') for date in dates]

# %%
tuplas=o.lista_archivos
# 
files = [tupla[0] for tupla in tuplas]
nombres=[tit.split("/")[-1:][0][:-4] for tit in files]
categorias=[cat.split("/")[7:-1] for cat in files]


nombres
# Out:
# ['Declaración responsable DNSH del proyecto ejecutado persona fisica',
#  'Reportaje fotográfico',
#  'Declaración de cesión y tratamiento de datos entidad beneficiaria resto',
#  'Reportaje fotográfico INSTALACIONES DE ALMACENAMIENTO',
#  'Declaración de autoconsumo del proyecto ejecutado',
#  'Declaración de cesión y tratamiento de datos entidad beneficiaria',
#  'Licencias y autorizaciones administrativas',
#  'Declaración de ausencia de conflicto de intereses entidad beneficiaria DACI autonomo',
#  'Proyecto MTD',
#  'Declaración de compromiso de cumplimiento de los principios transversales entidad beneficiaria',
#  'Certificado de Instalación Eléctrica',
#  'Declaración de compromiso de cumplimiento de los principios transversales entidad beneficiaria persona fisica',
#  'Reportaje fotográfico CON_SIN ALMACENAMIENTO',
#  'Declaración de ausencia de conflicto de intereses entidad beneficiaria DACI resto',
# ...

# %%
dd.split('/')[7:][:-1]
# Out:
# []
